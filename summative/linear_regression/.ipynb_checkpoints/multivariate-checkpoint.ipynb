# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Data/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
encoder = LabelEncoder()

to_be_encoded = ['sex', 'smoker', 'region']

for feature in to_be_encoded:
    df[feature] = encoder.fit_transform(df[feature])

df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, cmap='coolwarm')
# Out:
# <Axes: >

# %%
children = df.children
charges = df.charges

sns.scatterplot(x=children, y=charges)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
X_experiment = X_experiment
X_experiment = X_experiment.drop('region', axis=1)

sns.scatterplot(x=X_experiment.age * X_experiment.children, y = X_experiment.charges * X_experiment.children)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
for feature in df.columns:
    sns.scatterplot(x=df[feature], y=df.charges)
    plt.show()

# %%
colors = {'1': 'red', '2': 'blue'}

for category, color in colors.items():
    df_category = df[df['smoker'] == category]
    print(df_category.head()
    sns.scatterplot(x=df_category['charges'], y=df_category['charges'], color=color)

plt.show()

# %%
X_features = ['age', 'smoker', 'bmi']
X = df[X_features]
Y = df.charges

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = lr_model.predict(X_test)
mae = mean_absolute_error(Y_pred, Y_test)
mae
# Out:
# np.float64(4260.560091099395)

# %%
lr_model.score(X_test, Y_test)
# Out:
# 0.7776932310583374

# %%
X.columns
# Out:
# Index(['age', 'children', 'smoker'], dtype='object')

# %%
sns.scatterplot(x=df['bmi'], df[])
